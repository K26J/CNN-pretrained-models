# %% [markdown]
# <a href="https://colab.research.google.com/github/K26J/CNN-pretrained-models/blob/main/Universal_Classifier_using_ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model= ResNet50(weights= 'imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
img_path= '/content/Strawberry.png'
img= image.load_img(img_path, target_size=(224,224))
x= image.img_to_array(img) # Converting image into aaray
x= np.expand_dims(x, axis=0) # converting into batch
x= preprocess_input(x)

# %%
pred= model.predict(x)
print('Predicted:', decode_predictions(pred, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# Predicted: [('n07745940', 'strawberry', np.float32(0.999936)), ('n07753592', 'banana', np.float32(1.657465e-05)), ('n07614500', 'ice_cream', np.float32(8.9789855e-06))]
